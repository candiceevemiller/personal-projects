# %% [markdown]
# <a href="https://colab.research.google.com/github/candiceevemiller/personal-projects/blob/main/Curse%20of%20Strahd%20Tarokka.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import collections
from random import shuffle

Card = collections.namedtuple('Card', ['rank','suit'])

treasure_locations = [("The treasure lies in a dragon's house, in hands once clean and now corrupted", "The treasure is in the possesion of Vladimir Horngaard in Argynvostholt (ch7, areaQ36)"),
                      ("I see a sleeping Prince, a servant of light and the brother of darkness. The treasure lies with him.", "The reasure lies in Sergei's tomb (ch4, area K85)"),
                      ("Go to the mountains, climb the white tower guarded by golden knights.", "The treasure lies on the rooftop of the Tsolenka Pass guard tower (ch9, area T6)"),
                      ("The thing you seek lies with the dead, under mountains of gold coins.", "The treasure lies in a crypt in Castle Ravenloft (ch4, area k84, crypt31"),
                      ("Look for a den of wolves in the hills overlooking a mountain lake. The treasure belongs to Mother Night.", "The treasure lies in the shrine of Mother Night in the werewolf den (ch15, areaZ7"),
                      ("Find the Mad Dog's crypt. The treasure lies within, beneath blackened bones.", "The treasure lies in the crype of General Kroval 'Mad Dog' Grislek (ch4, area K84, crypt38)"),
                      ("I see a faceless god. He awaits you at the end of a long and winding road, deep in the moutains.","The treasure is inside the head of the giant statue in the Amber Temple (ch13, area X5a)"),
                      ("I see a throne fit for a king.", "The treasure lies in Castle Ravenloft's audience hall (ch4, area K25)"),
                      ("There is a town where all is not well. There you will find a house of corruption, and within, a dark room full of still ghosts.", "The treasure is hidden in the attic of the burgomaster's mansion in Vallaki (ch5, area N3s)"),
                      ("That which you seek lies in the womb of darkness, the devil's lair: the one place to which he must return", "The treasure lies in Strahd's tomb (ch4, area k86)"),
                      ("Go to a place of dizzying heights, where the stone itself is alive!", "The treasure lies in Castle Ravenloft's north tower peak (ch4, area k60)"),
                      ("Look to the one who sees all. The treasure is hidden in her camp.", "The treasure lies in Madam Eva's encampment (ch2, area G). If she si the one performing the card reading she says, 'I think the treasure is under my very nose!'"),
                      ("I see a kneeling woman - a rose of great beauty plucked too soon. The master of the marsh knows of whom I speak.", "The treasure lies under Marina's monument in Berez(ch10, area U5). 'The master of the marsh' refers to burgonmaster Lazlo Ulrich (area U2) whose ghost can point characters toward the monument."),
                      ("I see a fallen house guarded by a great stone dragon. Look to the highest peak.","The treasure lies in the beacon of Argynovstholt (ch7, area Q53). 'Great stone dragon' refers to the statue in area Q1."),
                      ("The treasure is hidden in a small castle beneath a mountain, guarded by amber giants.", "The treasure is inside a model of Castle Ravenloft in the Amber Temple (Ch13 area X20)"),
                      ("Search for the crypt of a wizard ordinaire. His staff is the key", "The treasure is hidden in the crypt of Fralmore Nimblenobs (ch4, area K84, crypt 37)"),
                      ("A man is not what he seems. He comes here in a carnival wagon. Therein lies what you seek.", "The treasure lies in Rictavio's carnival wagon (ch5, area N5)"),
                      ("A woman hangs above a roaring fire. Find her, and you will find the treasure", "The treasure lies in Castle Ravenloft's study (ch4, area K37)"),
                      ("I see a dead village, drowned by a river, ruled by one who has brought great evil into the world.", "The treasure is in Baba Lysaga's hut (ch10, area U3)"),
                      ("Look for a wizard's tower on a lake. Let the wizard's name and servant guide you to that which you seek.", "The treasure lies on the top floor of Van Richten's Tower (ch11, area V7)"),
                      ("I see the skeleton of a deadly warrior, lying on a bed of stone flanked by gargoyles.", "The treasure lies in the crypt of Endorovich (ch4, area K84, crypt 7)"),
                      ("Look to a place where sickness and madness are bred. Where children once cried, the treasure lies still.", "The treasure is in the nursery of the Abbey of Saint Markovia (ch8, area S23)"),
                      ("Look to the wizard of wines! In wood and sand the treasure hides.", "The treasure lies in the glassblower's workshop in the Wizard of Wines winery (ch12, area W10)"),
                      ("Seek a cask that once contained the finest wine, of which not a drop remains.", "The treasure lies in castle Ravenloft's wine cellar (ch4, area K63)"),
                      ("I see a dark room full of bottles. It is the tomb of a guild member.", "The treasure lies in the crypt of Artank Swilovich (ch4, area K84, crypt 5)"),
                      ("A wounded elf has what you seek. He will part with the treasure to see his dark dreams fulfilled.", "The treasure is hidden in Kasimir's hovel (ch5, area N9a)",),
                      ("What you seek lies at the crossroads of life and death, among the buried dead.", "The treasure is buried in the graveyard at the River Ivlis crossroads (ch2, area F)"),
                      ("The visitani have what you seek. A missing child holds the key to the treasure's release.", "The treasure is hidden in the Visitani treasure wagon (ch5 area N9i) 'A missing child' refers to Arabelle (see ch2, area L)."),
                      ("Look for a fortress inside a fortress, in a place hidden behind fire.", "The treasure lies in Castle Ravenloft's treasury (ch4 area K41)"),
                      ("I see a nest of ravens. There you will find the prize.", "The treasure is hidden in the attick of the Blue Water Inn (ch5, area N2q)"),
                      ("The treasure you seek is hidden behind the sun, in the house of a saint", "The treasure lies in the main hall of the Abbey of Saint Markovia (ch8, area S13)"),
                      ("I see a garden dusted with snow, watched over by a scarecrow with a sackcloth grin. Look not to the garden but to the guardian.", "The treasure is hidden inside one of the scarecrows in the garden of the Abbey of Saint Markovia (ch8, area S9)"),
                      ("Look to the west. Find a pool blessed by the light of the white sun.", "The treasure lies beneath the gazebo in the Shrine of the White Sun (ch8 area S4)"),
                      ("Find the mother - she who gave birth to evil.", "The treasure lies in the tomb of king Barov and Queen Ravenovia (ch4, area K88)"),
                      ("An evil tree grows atop a hill of graves where the ancient dead sleep. The ravens can help you find it. Look for the treasure there.", "The treasure lies at the base of the Gulthias tree (ch14, area Y4) any wereraven encountered in the wilderness can lead the characters to the location."),
                      ("I see a wall of bones, a chandelier of bones, and a table of bones - all that remains of enemies long forgotten.", "The treasure lies in Castle Ravenloft's hall of bones (ch4, area K67)"),
                      ("I see a lonely mill on a precipice. The treasure lies within.", "The treasure lies in the attic of Old Bonegrinder (ch6, area O4)"),
                      ("What you seek lies in a pile of treasure, beyond a set of amber doors.", "The treasure in the sealed treasury of the Amber Temple (ch13, area X40)"),
                      ("Look for a wealthy woman. A staunch ally of the devil, she keeps the treasure under lock and key, with the bones of an ancient enemy.", "The treasure is hidden in the master bedroom of Wachterhaus (ch5, area N4o)"),
                      ("You will find what you seek in the castle, amid the ruins of a place of supplication", "The Treasure lies in Castle Ravenloft's chappen (ch4, area K15)")
]

strahds_enemy_a = [("Look for an entertaining man with a monkey. This man is more than he seems", "This card refers to Rictavio (see Appendix D), who can be found at the Blue Water Inn in Vallaki (ch5, area N2). Normally reluctant to accompany the characters, Rictavio changes his tune if the characters tell him about the card reading. He sheds his disguise and intrduces himself as Dr. Rudolph Van Richten. The characters might think that Gadof Blinsky, the toymaker of Vallaki (area N7), is the figure they seek, because he has a pet monkey. If thye speak to him about this possibility, Blinsky jokes that he and the monkey are 'old friends', but if the charactres ask him to come with them to fight Strahd, he politely declines. If the characters tell him about the tarokka reading, Blinsky admits that he acquired the monkey from a half-elf carnival ringmaster named Rictavio."),
                   ("A werewolf holds a secret hatred for your enemy. Use her hatred to your advantage.", "This card refers to the werewolf Zuleika Toranescu (ch15, area Z7). She will accompany the characters if they promise to avenge her mate, Emil, by killing the leader of her pack, Kiril Stoyanovich."),
                   ("Your greatest ally will be a wizard. His mind is broken, but his spells are strong.", "This card refers to the Mad Mage of Mount Baratok (ch2, area M)."),
                   ("Ah the worst of all truths. You must face the evil of this land alone!", "There is no NPC who can inspire the characters."),
                   ("Search for a troubled young man surrounded by wealth and madness. His home is his prison.", "This card refers to Victor Vallakovich (ch5, area N3t). Realizing that the characters are the key to his salvation, he enthusastically leaves his home and accompanies them to Castle Ravenloft."),
                   ("Look for a dusk elf living among the Visitani. He has suffered a great loss and is haunted by his dark dreams. Help him, and he will help you in return.", "This card refers to Kasimir Velikov (ch5, area N9). The dusk elf accompanies the characters to Castle Ravenloft only after they lead him to the Amber Temple and help him find the means to resurrect his dead sister Patrina Velikovna."),
                   ("I have seen a fallen paladin of a fallen order of knights. He lingers like a ghost in a dead dragon's lair.", "This card refers to the revenant Sir Godfrey Gwilym (ch7 area Q37). Although initially unwilling to accompany the characters, he will do so if the characters convince him that the honor of the Order of the Silver Dragon can be restored with his help. Doing this requires a successful DC 15 Cha (Persuasion) check."),
                   ("Seek out the brother of the devil's bride. They call him 'the lesser,' but he has a powerful soul.", "This card refers to Ismark Kolyanovich (ch3, area E2). Ismark won't accompany the characters to Castle Ravenloft until he knows that his sister, Ireena Kolyana, is safe."),
                   ("I see a dead man of noble birth, guarded by his widow. Return life to the dead man's corpse, and he will be your staunch ally.", "This card refers to Nikolai Wachter, the elder, who is dead (ch5, area N4o). If the characters cast a raise dead spell or a resurrection spell on his preserved corpse, Nikolai (LN male human noble) agrees to help the characters once he feels well enough, despite his wife's protests. Although his family has long supported Strahd, Nikolai came to realize toward the end of his life that Strahd must be destroyed to save Barovia. If the characters don't have the means to raise Nikolai from the dead, Rictavio (App. D) gives them a spell scroll of raise dead if he learns of their need. If they're staying at the Blue Water Inn, he leaves the scroll in one of their rooms."),
                   ("I see a young man with a kind heart. A mother's boy! He is strong in body but weak of mind. Seek him out in the village of Barovia.", "This card refers to Parriwimple (ch3, area E1). Although he's a simpleton, he won't travel to Castle Ravenloft without a good cause. Characters can manipulate him into going by preying on his good heart. For instance, he might go there to help rescure missing Barovians, or to save the life of Ireena Kolyana, who is very beautiful. The characters must somehow deal with Bildrath, Parriwimple's employer, who won't let the foolish boy go to the castle for any reason."),
                   ("What horror is this? I see a man made by a man. Ageless and alone, it haunts the towers of the castle.", "This card refers to Pidlewick II (ch4, area K59 and app D)"),
                   ("A Vistana wanders  this land alone, searching for her mentor. She does not stay in one place for long. Seek her out at Saint Markovia's abbey, near the mists.", "This card refers to Ezmerelda d'Avenir (App D). She can be found in the Abbey of Saint Markovia (ch8, area S19), as well as several other locations throughout Barovia."),
                   ("Find the leader of the feathered ones who live among the vines. Though old, he has one more fight left in him.", "This card refers to Davian Martikov (ch12, 'The Wizard of Wines'). The old wereraven, realizing that he has a chance to end Strahd's tyranny, leaves his vineyard and winery in the capable hands of his sons Adrian and Elvir. But before he travels to Castle Ravenloft to face Strahd, Davian insists on reconcicling with his third son, Urwin Martikov (ch5, area N2)."),
                   ("I see a child - a Vistna. You must hrry, for her fate hangs in the balance. Find her at the lake!", "This card refers to Arabelle (ch2, area L). She gladly joins the party. But if she returns to her camp (ch5 area N9), her father, Luvash, refuses to let her leave."),
]

strahds_enemy_b = [("Look for an entertaining man with a monkey. This man is more than he seems", "This card refers to Rictavio (see Appendix D), who can be found at the Blue Water Inn in Vallaki (ch5, area N2). Normally reluctant to accompany the characters, Rictavio changes his tune if the characters tell him about the card reading. He sheds his disguise and intrduces himself as Dr. Rudolph Van Richten. The characters might think that Gadof Blinsky, the toymaker of Vallaki (area N7), is the figure they seek, because he has a pet monkey. If thye speak to him about this possibility, Blinsky jokes that he and the monkey are 'old friends', but if the charactres ask him to come with them to fight Strahd, he politely declines. If the characters tell him about the tarokka reading, Blinsky admits that he acquired the monkey from a half-elf carnival ringmaster named Rictavio."),
                   ("A werewolf holds a secret hatred for your enemy. Use her hatred to your advantage.", "This card refers to the werewolf Zuleika Toranescu (ch15, area Z7). She will accompany the characters if they promise to avenge her mate, Emil, by killing the leader of her pack, Kiril Stoyanovich."),
                   ("I see a man of faith whose sanity hangs by a thread. He has lost someone close to him.", "This card refers to Donavich, the priest of the village of Barovia (ch3, area E5). He will not accompany the characters until his son, Doru, is dead and buried."),
                   ("Ah the worst of all truths. You must face the evil of this land alone!", "There is no NPC who can inspire the characters."),
                   ("Find a girl driven to insanity, locked in the heart of her dead father's house. Curing her madness is key to your success.", "This card refers to Stella Wachter (ch5, area N4n). She grants the party no benefit unless her madness is cured. With her wits restored, Stella is happy to join the party and leave her rotten family behind."),
                   ("Look for a dusk elf living among the Visitani. He has suffered a great loss and is haunted by his dark dreams. Help him, and he will help you in return.", "This card refers to Kasimir Velikov (ch5, area N9). The dusk elf accompanies the characters to Castle Ravenloft only after they lead him to the Amber Temple and help him find the means to resurrect his dead sister Patrina Velikovna."),
                   ("Stir the spirit of the clumsy knight whose crypt lies deep within the castle.", "This card refers to Sir Klutz the phantom warrior (ch4, area K84). If Sir Klutz is Strahd's enemy, then the phantom arrior disappears not after seven days, but only after he or Strahd is reduced to 0 hit points."),
                   ("Seek out the brother of the devil's bride. They call him 'the lesser,' but he has a powerful soul.", "This card refers to Ismark Kolyanovich (ch3, area E2). Ismark won't accompany the characters to Castle Ravenloft until he knows that his sister, Ireena Kolyana, is safe."),
                   ("A man of death named Arrigal will forsake his dark lord to serve your cause. Beware! He has a rotten soul.", "This card refers to the Vistani assassin Arrigal (ch5, area N9c). If the characters mention this card reading to him, he accepts his fate and accompanies them. If the characters succeed in defeating Strahd, Arrigal betrays and attacks them, believing that he is destined to become Barovia's new lord."),
                   ("Evil's bride is the one you seek!", "This card refers to Ireena Kolyana (ch3, area E4). Her brother, Ismark, opposes the idea of Ireena's being taken to Castle Ravenloft, but she insists on going there once the characters tell her about the card reading. Ireena won't accompany the characters, however, until Kolyan Indirovich's body is laid to rest in the cemetary."),
                   ("Look for a man of music, a man with two heads. He lives in a place of great hunger and sorrow.", "This card refers to Clovin Belview (ch8, area S17), the two-headed mongrelfolk. Clovin serves the Abbot out of fear and a perverse sense of loyalty. His job is to deliver food to the other mongrelfolk, whom he abhors. If the Abbot still lives, Clovin doesn't want to earn his master's ire by attempting to leave, and he refuses to accompany the characters. But if the Abbot dies, Clovin doesn't have any reason to remain in the abbey, so he's willing to come along if he is bribed with wine. Clovin provides no benefit to the party without his viol."),
                   ("A Vistana wanders  this land alone, searching for her mentor. She does not stay in one place for long. Seek her out at Saint Markovia's abbey, near the mists.", "This card refers to Ezmerelda d'Avenir (App D). She can be found in the Abbey of Saint Markovia (ch8, area S19), as well as several other locations throughout Barovia."),
                   ("Find the leader of the feathered ones who live among the vines. Though old, he has one more fight left in him.", "This card refers to Davian Martikov (ch12, 'The Wizard of Wines'). The old wereraven, realizing that he has a chance to end Strahd's tyranny, leaves his vineyard and winery in the capable hands of his sons Adrian and Elvir. But before he travels to Castle Ravenloft to face Strahd, Davian insists on reconcicling with his third son, Urwin Martikov (ch5, area N2)."),
                   ("I hear a wedding bell, or perhaps a death knell. It calls thee to a mountainside abbey, wherein you will find a woman who is more than the sum of her parts.", "This card refers to Vasilka the flesh golem (ch8 area S13)")
]

strahd = [("He lurks in the darkness where the morning light once shone  - a sacred place.", "Strahd faces the characters in the chapel (area K15)."),
          ("The beast sits on his dark throne", "Strahd faces the characters in the audience hall (area K25)"),
          ("He haunts the tomb of the man he envied above all.", "Strahd faces the characters in Sergei's tomb (area K85)"),
          ("He lurks in the depths of darkness, in the one place to which he must return", "Strahd faces the characters in his tomb (area K86)"),
          ("He lurks in a hall of bones, in the dark pits of his castle", "Strahd faces the characters in the hall of bones (area K67)"),
          ("He waits for you in a place of wisdom, warmth, and despair. Great secrets are there.", "Strahd faces the characters in the study (area K37)"),
          ("Look to the father's tomb", "Strahd faces the characters in the tomb of King Barov and Queen Ravenovia (area K88)"),
          ("I see a dark figure on a balcony, looking down upon this tortured land with a twisted smile", "Strahd faces the characters at the overlook (area K6)"),
          ("He lurks in the one place to which he must return - a place of death.", "Strahd faces the characters in his tomb (area K86)"),
          ("He dwells with the one whose blood sealed his doom, a brother of light snuffed out too soon.", "Strahd faces the characters in Sergei's tomb (area K85)"),
          ("Look to great heights. Find the beating heart of the castle. He waits nearby.", "Strahd faces the characters in the north tower peak (area K60)"),
          ("The cards can't see where the evil lurks. The mists obscure all.", "This card offers no clue about where the funal showdown with Strahd will occur it can happen anywhere you like in Castle Ravenloft. Alternatively, Madam Eva tells the characters to return to her after at least three days, and she will consult the cards again for them, but only to discern the location of their enemy."),
          ("Look to the mother's tomb.", "Strahd faces the characters in the tomb of King Barov and Queen Ravenovia (area K88)"),
          ("I see a secret place - a vault of temptation hidden behind a woman of great beauty. The evil waits atop his tower of treasure.", "Strahd confronts the characters in the treasury (area K41). 'A woman of great beauty' refers to the portrait of Tatyana hanging in the castle's study (area K37), which contains a secret door that leads to the treasury.")
]

class LowTarokka:
  ranks = [str(n) for n in range(1,10)]+['Master']
  suits = 'Swords Stars Coins Glyphs'.split()

  def __init__(self):
    self._cards =  [Card(rank, suit) for suit in self.suits for rank in self.ranks]
    self.treasure_lookup = dict(zip(self._cards, treasure_locations))

  def __len__(self):
    return len(self._cards)

  def __repr__(self):
    return f'Low Tarokka Deck containing {len(self)} cards'

  def __getitem__(self, position):
    return self._cards[position]

  def __setitem__(self,position,card):
    self._cards[position] = card

  def __add__(self, other):
    return self._cards + other._cards

  def __radd__(self,other):
    return other._cards + self._cards

class HighTarokka:
  tarokka_high = ['Artifact', 'Beast', 'Broken One', 'Darklord', 'Donjon', 'Seer',
                  'Ghost', 'Executioner', 'Horseman', 'Innocent', 'Marionette', 'Mists',
                  'Raven', 'Tempter', ]
  
  def __init__(self):
    self._cards = [Card(rank, 'High Tarokka') for rank in self.tarokka_high]
    self.strahd_lookup = dict(zip(self._cards, strahd))
    self.strahds_enemy_a_lookup = dict(zip(self._cards, strahds_enemy_a))
    self.strahds_enemy_b_lookup = dict(zip(self._cards, strahds_enemy_b))

  def __len__(self):
    return len(self._cards)

  def __repr__(self):
    return f'High Tarokka Deck containing {len(self)} cards'

  def __getitem__(self,position):
    return self._cards[position]

  def __setitem__(self,position,card):
    self._cards[position] = card

  def __add__(self,other):
    return self._cards + other._cards

  def __radd__(self,other):
    return other._cards + self._cards

class TarokkaDeck:

  def __init__(self):
    self.reset()

  def __len__(self):
    return len(self._cards)

  def __repr__(self):
    return f'Tarokka Deck containing {len(self)} cards, {len(self.high)} High Tarokka, and {len(self.low)} Low Tarokka'

  def __getitem__(self,position):
    return self._cards[position]

  def __setitem__(self, position, card):
    self._cards[position] = card
  
  def __add__(self,other):
    return self._cards + other._cards

  def __radd__(self,other):
    return other._cards + self._cards

  def reset(self):
    self.low = LowTarokka()
    self.high = HighTarokka()
    self._cards = self.low + self.high
    return None
  
  def draw_high(self, num_cards=5):
    shuffle(self.high)
    rtn_val = self.high[:num_cards]
    self.reset()
    return rtn_val

  def draw_low(self, num_cards=5):
    shuffle(self.low)
    rtn_val = self.low[:num_cards]
    self.reset()
    return rtn_val

  def draw(self, num_cards=5):
    shuffle(self)
    rtn_val = self[:num_cards]
    self.reset()
    return rtn_val

  def five_card_spread(self):
    _draw = self.draw_low(3) + self.draw_high(2)
    print(f"The Tome of Strahd:\n    Card: {_draw[0]}\n    Read: {self.low.treasure_lookup[_draw[0]][0]}\n    Loc: {self.low.treasure_lookup[_draw[0]][1]}\n")
    print(f"The Holy Symbol of Ravenkind:\n    Card: {_draw[1]}\n    Read: {self.low.treasure_lookup[_draw[1]][0]}\n    Loc: {self.low.treasure_lookup[_draw[1]][1]}\n")
    print(f"The Sunsword:\n    Card: {_draw[0]}\n    Read: {self.low.treasure_lookup[_draw[2]][0]}\n    Loc: {self.low.treasure_lookup[_draw[2]][1]}\n")
    if self.high.strahds_enemy_a_lookup[_draw[3]] == self.high.strahds_enemy_b_lookup[_draw[3]]:
      print(f"Strahd's Enemy:\n    Card: {_draw[3]}\n    Read: {self.high.strahds_enemy_a_lookup[_draw[3]][0]}\n    Loc: {self.high.strahds_enemy_a_lookup[_draw[3]][1]}\n")
    else:
      print(f"Strahd's Enemy:\n    Card: {_draw[3]}\n    Option A:\n        Read: {self.high.strahds_enemy_a_lookup[_draw[3]][0]}\n        Loc: {self.high.strahds_enemy_a_lookup[_draw[3]][1]}\n")
      print(f"    Option B:\n        Read: {self.high.strahds_enemy_b_lookup[_draw[3]][0]}\n        Loc: {self.high.strahds_enemy_b_lookup[_draw[3]][1]}\n")
    print(f"Strahd:\n    Card: {_draw[4]}\n    Read: {self.high.strahd_lookup[_draw[4]][0]}\n    Loc: {self.high.strahd_lookup[_draw[4]][1]}\n")

# %%
deck = TarokkaDeck()

# %%
deck.five_card_spread()
# Out:
# The Tome of Strahd:
#     Card: Card(rank='7', suit='Coins')
#     Read: What you seek lies at the crossroads of life and death, among the buried dead.
#     Loc: The treasure is buried in the graveyard at the River Ivlis crossroads (ch2, area F)
#
# The Holy Symbol of Ravenkind:
#     Card: Card(rank='6', suit='Coins')
#     Read: A wounded elf has what you seek. He will part with the treasure to see his dark dreams fulfilled.
#     Loc: The treasure is hidden in Kasimir's hovel (ch5, area N9a)
#
# The Sunsword:
#     Card: Card(rank='7', suit='Coins')
#     Read: Find the mother - she who gave birth to evil.
#     Loc: The treasure lies in the tomb of king Barov and Queen Ravenovia (ch4, area K88)
#
# Strahd's Enemy:
#     Card: Card(rank='Innocent', suit='High Tarokka')
#     Option A:
#         Read: I see a young man with a kind heart. A mother's boy! He is strong in body but weak of mind. Seek him out in the village of Barovia.
# ...
