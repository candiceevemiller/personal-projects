# %% [markdown]
# <a href="https://colab.research.google.com/github/candiceevemiller/personal-projects/blob/main/NLTK_practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import nltk, re, pprint
from nltk import word_tokenize

# %%
from urllib import request
url_dracula = 'https://www.gutenberg.org/files/345/345-0.txt'
url_frankenstein = 'https://www.gutenberg.org/files/84/84-0.txt'

dracula_raw = request.urlopen(url_dracula).read().decode('utf8')
frankenstein_raw = request.urlopen(url_frankenstein).read().decode('utf8')

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
dracula_tokens = word_tokenize(dracula_raw)
frankenstein_tokens = word_tokenize(frankenstein_raw)

dracula = nltk.Text(dracula_tokens)
frankenstein = nltk.Text(frankenstein_tokens)

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
dracula.collocations()
# Out:
# Van Helsing; Madam Mina; Lord Godalming; Dr. Seward; Project
# Gutenberg-tm; Mrs. Harker; Dr. Van; could see; friend John; Mr.
# Morris; Project Gutenberg; _Czarina Catherine_; Miss Lucy; United
# States; last night; Quincey Morris; Literary Archive; Gutenberg-tm
# electronic; Mrs. Westenra; electronic works

# %%
dracula_raw.find('CHAPTER I'), dracula_raw.rfind("END OF THE PROJECT GUTENBERG EBOOK DRACULA")
# Out:
# (1680, 862453)

# %%
dracula_raw = dracula_raw[1680:862453]

# %%
frankenstein_raw.find("Letter 1"), frankenstein_raw.rfind('END OF THE PROJECT GUTENBERG EBOOK FRANKENSTEIN')
# Out:
# (1102, 427702)

# %%
frankenstein_raw = frankenstein_raw[1102:427702]

# %%
frankenstein_raw = frankenstein_raw.lower()
dracula_raw = dracula_raw.lower()

dracula_tokens = word_tokenize(dracula_raw)
frankenstein_tokens = word_tokenize(frankenstein_raw)

dracula = nltk.Text(dracula_tokens)
frankenstein = nltk.Text(frankenstein_tokens)

# %%
dracula.collocations()
# Out:
# van helsing; madam mina; dr. seward; lord godalming; mrs. harker;
# friend john; dr. van; could see; last night; mr. morris; _czarina
# catherine_; miss lucy; quincey morris; poor dear; mrs. westenra; dear
# madam; poor lucy; mr. hawkins; jonathan harker; thank god

# %%
dracula.concordance('vampire')
# Out:
# Displaying 25 of 27 matches:
# mething that is either were-wolf or vampire . ( _mem._ , i must ask the count a
# loose , or one be bred there from a vampire . these things do occur , you know
#  the common . she was bitten by the vampire when she was in a trance , sleep-wa
# p of his arm to designate what to a vampire was `` home '' -- '' their face sho
# his instinct is satisfied as to the vampire 's ultimate triumph ? stay ; he is
#  yet more power to work evil . this vampire which is amongst us is of himself s
# ombination -- a power denied to the vampire kind ; we have sources of science ;
#  us consider the limitations of the vampire in general , and of this one in par
# ry eyes . take it , then , that the vampire , and the belief in his limitations
# our own so unhappy experience . the vampire live on , and can not die by mere p
#  is in a stupor such as we know the vampire can produce . we can do nothing wit
# ...

# %%
frankenstein.concordance('monster')
# Out:
# Displaying 25 of 30 matches:
# , i beheld the wretch—the miserable monster whom i had created . he held up the
# ng about . i dreaded to behold this monster , but i feared still more that henr
# e ! save me ! ” i imagined that the monster seized me ; i struggled furiously a
# stored me to life . the form of the monster on whom i had bestowed existence wa
# lmost began to think that i was the monster that he said i was . he threatened
#  and i lived in daily fear lest the monster whom i had created should perpetrat
# our remaining friends. ” “ abhorred monster ! fiend that thou art ! the torture
# convinced that i was in reality the monster that i am , i was filled with the b
#  of none like me . was i , then , a monster , a blot upon the earth , from whic
# cursed creator ! why did you form a monster so hideous that even _you_ turned f
# ntly . ‘ let me go , ’ he cried ; ‘ monster ! ugly wretch ! you wish to eat me
# ...

# %%
frankenstein.similar('monster')
# Out:
# fiend murderer day scene sun man time path feelings creature friends
# door cottage will as desolation sea boat mind prospect

# %%
frankenstein.common_contexts(['monster','man'])
# Out:
# the_whom the_saw a_has

# %%
dracula.dispersion_plot(['vampire', 'helsing', 'dracula', 'blood'])

# %%
frankenstein.dispersion_plot(['victor', 'monster', 'frankenstein', 'creature', 'fire'])

# %%
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
nltk.pos_tag(dracula)
# Out:
# [('chapter', 'NN'),
#  ('i.', 'NN'),
#  ('jonathan', 'NN'),
#  ('harker', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('journal', 'JJ'),
#  ('chapter', 'NN'),
#  ('ii', 'NN'),
#  ('.', '.'),
#  ('jonathan', 'NN'),
#  ('harker', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('journal', 'JJ'),
#  ('chapter', 'NN'),
#  ('iii', 'NN'),
#  ('.', '.'),
#  ('jonathan', 'NN'),
#  ('harker', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('journal', 'JJ'),
#  ('chapter', 'NN'),
#  ('iv', 'NN'),
#  ('.', '.'),
#  ('jonathan', 'NN'),
#  ('harker', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('journal', 'JJ'),
#  ('chapter', 'NN'),
#  ('v.', 'NN'),
#  ('letters—lucy', 'NN'),
#  ('and', 'CC'),
#  ('mina', 'NN'),
#  ('chapter', 'NN'),
#  ('vi', 'NN'),
#  ('.', '.'),
#  ('mina', 'CC'),
#  ('murray', 'JJ'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('journal', 'JJ'),
#  ('chapter', 'NN'),
#  ('vii', 'NN'),
#  ('.', '.'),
#  ('cutting', 'VBG'),
#  ('from', 'IN'),
#  ('“', 'VBG'),
#  ('the', 'DT'),
# ...

# %%
nltk.pos_tag(frankenstein)
# Out:
# [('letter', 'NN'),
#  ('1', 'CD'),
#  ('letter', 'NN'),
#  ('2', 'CD'),
#  ('letter', 'NN'),
#  ('3', 'CD'),
#  ('letter', 'NN'),
#  ('4', 'CD'),
#  ('chapter', 'NN'),
#  ('1', 'CD'),
#  ('chapter', 'NN'),
#  ('2', 'CD'),
#  ('chapter', 'NN'),
#  ('3', 'CD'),
#  ('chapter', 'NN'),
#  ('4', 'CD'),
#  ('chapter', 'NN'),
#  ('5', 'CD'),
#  ('chapter', 'NN'),
#  ('6', 'CD'),
#  ('chapter', 'NN'),
#  ('7', 'CD'),
#  ('chapter', 'NN'),
#  ('8', 'CD'),
#  ('chapter', 'NN'),
#  ('9', 'CD'),
#  ('chapter', 'NN'),
#  ('10', 'CD'),
#  ('chapter', 'NN'),
#  ('11', 'CD'),
#  ('chapter', 'NN'),
#  ('12', 'CD'),
#  ('chapter', 'NN'),
#  ('13', 'CD'),
#  ('chapter', 'NN'),
#  ('14', 'CD'),
#  ('chapter', 'NN'),
#  ('15', 'CD'),
#  ('chapter', 'NN'),
#  ('16', 'CD'),
#  ('chapter', 'NN'),
#  ('17', 'CD'),
#  ('chapter', 'NN'),
#  ('18', 'CD'),
#  ('chapter', 'NN'),
#  ('19', 'CD'),
#  ('chapter', 'NN'),
#  ('20', 'CD'),
#  ('chapter', 'NN'),
#  ('21', 'CD'),
#  ('chapter', 'NN'),
#  ('22', 'CD'),
# ...

# %%
dracula_vocab = sorted(set(dracula))
frankenstein_vocab = sorted(set(frankenstein))
len(dracula_vocab), len(frankenstein_vocab)
# Out:
# (10034, 7351)

# %%
nltk.download('inaugural')
nltk.download('nps_chat')
nltk.download('webtext')
nltk.download()
# Out:
# [nltk_data] Downloading package inaugural to /root/nltk_data...
# [nltk_data]   Package inaugural is already up-to-date!
# [nltk_data] Downloading package nps_chat to /root/nltk_data...
# [nltk_data]   Package nps_chat is already up-to-date!
# [nltk_data] Downloading package webtext to /root/nltk_data...
# [nltk_data]   Package webtext is already up-to-date!
# NLTK Downloader
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# Downloader> d
#
# Download which package (l=list; x=cancel)?
#   Identifier> books
#     Error loading books: Package 'books' not found in index
#
# ---------------------------------------------------------------------------
#     d) Download   l) List    u) Update   c) Config   h) Help   q) Quit
# ---------------------------------------------------------------------------
# ...

# %%
from nltk.book import *

fdist_dracula = FreqDist(dracula)
fdist_frankenstein = FreqDist(frankenstein)

# %%
fdist_dracula.most_common(50)
# Out:
# [(',', 11242),
#  ('the', 7904),
#  ('.', 7286),
#  ('and', 5899),
#  ('i', 4830),
#  ('to', 4471),
#  ('of', 3626),
#  ('a', 2916),
#  ('he', 2575),
#  ('in', 2504),
#  ('that', 2482),
#  ('it', 2172),
#  ("''", 1989),
#  ('was', 1887),
#  (';', 1683),
#  ('as', 1589),
#  ('we', 1552),
#  ('for', 1536),
#  ('is', 1506),
#  ('not', 1485),
#  ('his', 1471),
#  ('--', 1461),
#  ('me', 1453),
#  ('you', 1409),
#  ('with', 1285),
#  ('my', 1258),
#  ('all', 1156),
#  ('be', 1115),
#  ('so', 1106),
#  ('at', 1081),
#  ('on', 1073),
#  ('but', 1070),
#  ('have', 1062),
#  ('her', 1059),
#  ('had', 1045),
#  ('him', 951),
#  ('``', 942),
#  ('she', 817),
#  ('there', 779),
#  ('when', 776),
#  ('!', 751),
#  ('which', 663),
#  ('*', 655),
#  ('if', 638),
#  ("'s", 633),
#  ('this', 630),
#  ('from', 624),
#  (':', 620),
#  ('are', 579),
#  ('said', 570)]

# %%
from nltk import ngrams

dracula_bigrams = list(bigrams(dracula))
frankenstein_bigrams = list(bigrams(frankenstein))
dracula_trigrams = list(ngrams(dracula,3))
frankenstein_trigrams = list(ngrams(frankenstein,3))

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.preprocessing.text import Tokenizer

tokenizer = Tokenizer()
tokenizer.fit_on_texts([dracula_raw,frankenstein_raw])
word_index = tokenizer.word_index
print(word_index)
# Out:
# {'the': 1, 'and': 2, '\r': 3, 'i': 4, 'to': 5, 'of': 6, 'a': 7, 'in': 8, 'that': 9, 'he': 10, 'my': 11, 'was': 12, 'it': 13, 'me': 14, 'as': 15, 'for': 16, 'you': 17, 'with': 18, 'his': 19, 'not': 20, 'is': 21, 'but': 22, 'we': 23, 'had': 24, 'on': 25, 'be': 26, 'her': 27, 'have': 28, 'at': 29, 'all': 30, 'so': 31, 'which': 32, 'the\r': 33, 'him': 34, 'when': 35, 'she': 36, 'this': 37, 'from': 38, 'by': 39, 'there': 40, 'were': 41, 'if': 42, 'are': 43, 'and\r': 44, 'one': 45, 'said': 46, 'could': 47, 'then': 48, 'will': 49, 'no': 50, 'they': 51, 'or': 52, 'would': 53, 'them': 54, 'what': 55, 'do': 56, 'i\r': 57, 'some': 58, 'now': 59, 'been': 60, 'us': 61, 'of\r': 62, 'your': 63, 'up': 64, 'to\r': 65, 'more': 66, 'may': 67, 'shall': 68, 'time': 69, 'our': 70, 'must': 71, 'an': 72, 'out': 73, 'am': 74, 'can': 75, 'who': 76, 'see': 77, 'know': 78, 'before': 79, 'night': 80, 'a\r': 81, 'only': 82, 'into': 83, 'did': 84, 'over': 85, 'has': 86, 'their': 87, 'come': 88, 'man': 89, 'any': 9
# ...
